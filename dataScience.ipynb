# %% [markdown]
# ng

# %% [markdown]
# # Data science is the process of using data,science and machine  learning to discover useful insight,solve problems and make better decision.
#
# what to learn
# # 1.1 programming
# # 1 python
#
# # data processing
# # 3 numpy
# # 4 pandas
# # 5 math and statistic
#     probability
#     statistic
#     leaner algebra
#
# # 6 machine learning
#     supervise learning
#     unsupervise learning
#     reinforcement learning

# %% [markdown]
# # Introduction to Numpy
# Numpy is a core python library for numerical computing that provides fast array processing and mathematical functions.
